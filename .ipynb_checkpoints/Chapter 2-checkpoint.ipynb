# %% [markdown]
# # Chapter 2 examples
#
# This notebook covers ....
#
# ## Section 2.3: Classical confidence Intervals (CIs)

# %% [markdown]
# ### *CI for continuous data*
#
# Recall:
# - length(y) returns the number of elements of the vector y
# - mean() and sd() return the means and standard deviation
# - sqrt() returns the square root
# - qt(p,df) returns the pth quantile of the t-distribution with degrees of freedom equal to df, that is the probability of observing a value less than this quantile is p.

# %%
y <- c(35,34,38,35,37)
n <- length(y)
estimate <- mean(y)
se <- sd(y)/sqrt(n)
int.95 <- estimate + qt(c(.025,.975),n-1)*se
print(int.95)
# Out:
# [1] 33.75974 37.84026

# %% [markdown]
#                     Question: why are int.50 and int.95 each vectors of length 2?

# %% [markdown]
# ### *CI for proportions*
#
# Recall: the standard error of a proportion is given by $\sqrt{p*(1-p)/n}$

# %%
y <- 700
n <- 1000
estimate <- y/n
se <- sqrt (estimate*(1-estimate)/n)
int.95 <- estimate + qnorm(c(.025,.975))*se
print(int.95)
# Out:
# [1] 0.6715974 0.7284026

# %% [markdown]
# ### *CI for discrete data*
#
# Note for discrete data, we use the same approach as for continuous data to calculate confidence intervals.

# %%
y <- rep (c(0,1,2,3,4), c(600,300,50,30,20))
n <- length(y)
estimate <- mean(y)
se <- sd(y)/sqrt(n)
int.95 <- estimate + qt(c(.025,.975),n-1)*se
print(int.95)
# Out:
# [1] 0.5156936 0.6243064

# %% [markdown]
#         Question: what are the advantages/disadvantages of using table() or summary() to summarize discrete data?

# %%
summary(y)
table(y)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    0.00    0.00    0.57    1.00    4.00
# y
#   0   1   2   3   4
# 600 300  50  30  20

# %% [markdown]
#                 Question: what type of plot can we use to summarize discrete data?

# %%
library(ggplot2)
dog.dta <- data.frame(y=y)
plot1 <- ggplot(dog.dta,aes(factor(y)))
plot1 + geom_bar(fill="lightgrey", colour="darkblue",width=.5)
# Out:
# plot without title

# %% [markdown]
# ### Visualize CIs with scatterplot (Figure 2.3 of text)
#
# First, let's read in the data and look at it:

# %%
par (mar=c(5,5,4,2)+.1)
polls <- matrix (scan("http://www.stat.columbia.edu/~gelman/arm/examples/death.polls/polls.dat"), ncol=5, byrow=TRUE)
head(polls)
# Out:
#      [,1] [,2] [,3] [,4] [,5]
# [1,] 2002   10   70   25    5
# [2,] 2002    5   72   25    3
# [3,] 2001   10   68   26    6
# [4,] 2001    5   65   27    8
# [5,] 2001    2   67   25    8
# [6,] 2000    8   67   28    5

# %%
support <- polls[,3]/(polls[,3]+polls[,4])
year <-  polls[,1] + (polls[,2]-6)/12
plot (year, support*100, xlab="Year", ylim=c(min(100*support)-1, max(100*support)+1),
      ylab="Percentage support for the death penalty", cex=1.1, cex.main=1.2,
      cex.axis=1.1, cex.lab=1.1, pch=20)
for (i in 1:nrow(polls))
  lines (rep(year[i],2), 100*(support[i]+c(-1,1)*sqrt(support[i]*(1-support[i])/1000)))
# Out:
# plot without title

# %%
# CI using simulations

n.men <- 500
p.hat.men <- 0.75
se.men <- sqrt (p.hat.men*(1-p.hat.men)/n.men)

n.women <- 500
p.hat.women <- 0.65
se.women <- sqrt (p.hat.women*(1-p.hat.women)/n.women)

n.sims <- 10000
p.men <- rnorm (n.sims, p.hat.men, se.men)
p.women <- rnorm (n.sims, p.hat.women, se.women)
ratio <- p.men/p.women
int.95 <- quantile (ratio, c(.025,.975))
print(int.95)
